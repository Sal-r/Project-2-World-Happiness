# %%
import pandas as pd
from functools import reduce

# %%
df_15 = pd.read_csv("2015_happiness.csv") 
df_16 = pd.read_csv("2016_happiness.csv") 
df_17 = pd.read_csv("2017_happiness.csv") 
df_18 = pd.read_csv("2018_happiness.csv") 
df_19 = pd.read_csv("2019_happiness.csv")

# %%
df_15 = df_15[['Country', 'HappinessRank', 'HappinessScore', 'Economy', 'Generosity', 'Trust', 'Health', 'Freedom']]
df_16 = df_16[['Country', 'HappinessRank', 'HappinessScore', 'Economy', 'Generosity', 'Trust', 'Health', 'Freedom']]
df_17 = df_17[['Country', 'HappinessRank', 'HappinessScore', 'Economy', 'Generosity', 'Trust', 'Health', 'Freedom']]
df_18 = df_18[['Country', 'HappinessRank', 'HappinessScore', 'Economy', 'Generosity', 'Trust', 'Health', 'Freedom']]
df_19 = df_19[['Country', 'HappinessRank', 'HappinessScore', 'Economy', 'Generosity', 'Trust', 'Health', 'Freedom']]

# %%
df_18
# Out:
#                       Country  HappinessRank  HappinessScore  Economy  \
# 0                     Finland              1           7.632    1.305
# 1                      Norway              2           7.594    1.456
# 2                     Denmark              3           7.555    1.351
# 3                     Iceland              4           7.495    1.343
# 4                 Switzerland              5           7.487    1.420
# ..                        ...            ...             ...      ...
# 151                     Yemen            152           3.355    0.442
# 152                  Tanzania            153           3.303    0.455
# 153               South Sudan            154           3.254    0.337
# 154  Central African Republic            155           3.083    0.024
# 155                   Burundi            156           2.905    0.091
#
#      Generosity  Trust  Health  Freedom
# 0         0.202  0.393   0.874    0.681
# 1         0.286  0.340   0.861    0.686
# ...

# %%
df_15.to_csv('2015_happiness.csv', encoding='utf-8', index=False)
df_16.to_csv('2016_happiness.csv', encoding='utf-8', index=False)
df_17.to_csv('2017_happiness.csv', encoding='utf-8', index=False)
df_18.to_csv('2018_happiness.csv', encoding='utf-8', index=False)
df_19.to_csv('2019_happiness.csv', encoding='utf-8', index=False)
