# %%
import pandas as pd

# %%
df_2015 = pd.read_csv (r'2015_happiness.csv')
#print(df_2015)

df_2015 = df_2015.drop(columns=['Standard_Error', 'Family', 'Dystopia_Residual'], axis = 1)
#2015_

#print(2015_correlation_economy)
#print(2015_correlation_health)
#print(2015_correlation_freedom)
#print(2015_correlation_trust)
#print(2015_correlation_generosity)

# %%
df_2015.corr()
# Out:
#                 HappinessRank  HappinessScore   Economy    Health   Freedom  \
# HappinessRank        1.000000       -0.992105 -0.785267 -0.735613 -0.556886
# HappinessScore      -0.992105        1.000000  0.780966  0.724200  0.568211
# Economy             -0.785267        0.780966  1.000000  0.816478  0.370300
# Health              -0.735613        0.724200  0.816478  1.000000  0.360477
# Freedom             -0.556886        0.568211  0.370300  0.360477  1.000000
# Trust               -0.372315        0.395199  0.307885  0.248335  0.493524
# Generosity          -0.160142        0.180319 -0.010465  0.108335  0.373916
#
#                    Trust  Generosity
# HappinessRank  -0.372315   -0.160142
# HappinessScore  0.395199    0.180319
# Economy         0.307885   -0.010465
# Health          0.248335    0.108335
# Freedom         0.493524    0.373916
# Trust           1.000000    0.276123
# Generosity      0.276123    1.000000

# %%
df_2016 = pd.read_csv (r'2016_happiness.csv')

df_2016 = df_2016.drop(columns=['Lower_Confidence_Interval', 'Upper_Confidence_Interval', 'Family', 'Dystopia_Residual'], axis = 1)

#print(df_2016)

# %%
df_2016.corr()
# Out:
#                 HappinessRank  HappinessScore   Economy    Health   Freedom  \
# HappinessRank        1.000000       -0.995743 -0.793577 -0.767991 -0.557169
# HappinessScore      -0.995743        1.000000  0.790322  0.765384  0.566827
# Economy             -0.793577        0.790322  1.000000  0.837067  0.362283
# Health              -0.767991        0.765384  0.837067  1.000000  0.341199
# Freedom             -0.557169        0.566827  0.362283  0.341199  1.000000
# Trust               -0.387102        0.402032  0.294185  0.249583  0.502054
# Generosity          -0.145369        0.156848 -0.025531  0.075987  0.361751
#
#                    Trust  Generosity
# HappinessRank  -0.387102   -0.145369
# HappinessScore  0.402032    0.156848
# Economy         0.294185   -0.025531
# Health          0.249583    0.075987
# Freedom         0.502054    0.361751
# Trust           1.000000    0.305930
# Generosity      0.305930    1.000000

# %%
df_2017 = pd.read_csv (r'2017_happiness.csv')

df_2017 = df_2017.drop(columns=['Whisker_high', 'Whisker_low', 'Family', 'Dystopia_Residual'], axis = 1)

#print(df_2017)

# %%
df_2017.corr()
# Out:
#                 HappinessRank  HappinessScore   Economy    Health   Freedom  \
# HappinessRank        1.000000       -0.992774 -0.813244 -0.780716 -0.551608
# HappinessScore      -0.992774        1.000000  0.812469  0.781951  0.570137
# Economy             -0.813244        0.812469  1.000000  0.843077  0.369873
# Health              -0.780716        0.781951  0.843077  1.000000  0.349827
# Freedom             -0.551608        0.570137  0.369873  0.349827  1.000000
# Generosity          -0.132620        0.155256 -0.019011  0.063191  0.316083
# Trust               -0.405842        0.429080  0.350944  0.279752  0.499183
#
#                 Generosity     Trust
# HappinessRank    -0.132620 -0.405842
# HappinessScore    0.155256  0.429080
# Economy          -0.019011  0.350944
# Health            0.063191  0.279752
# Freedom           0.316083  0.499183
# Generosity        1.000000  0.294159
# Trust             0.294159  1.000000

# %%
df_2018 = pd.read_csv (r'2018_happiness.csv')

df_2018 = df_2018.drop(columns=['Social_support'], axis = 1)

#print(df_2018)

# %%
df_2018.corr()
# Out:
#                 HappinessRank  HappinessScore   Economy    Health   Freedom  \
# HappinessRank        1.000000       -0.991749 -0.805897 -0.778700 -0.530786
# HappinessScore      -0.991749        1.000000  0.802124  0.775814  0.544280
# Economy             -0.805897        0.802124  1.000000  0.844273  0.332275
# Health              -0.778700        0.775814  0.844273  1.000000  0.355475
# Freedom             -0.530786        0.544280  0.332275  0.355475  1.000000
# Generosity          -0.103602        0.135825 -0.011241  0.020751  0.297988
# Trust               -0.371133        0.405292  0.319582  0.315569  0.462446
#
#                 Generosity     Trust
# HappinessRank    -0.103602 -0.371133
# HappinessScore    0.135825  0.405292
# Economy          -0.011241  0.319582
# Health            0.020751  0.315569
# Freedom           0.297988  0.462446
# Generosity        1.000000  0.362249
# Trust             0.362249  1.000000

# %%
df_2019 = pd.read_csv (r'2019_happiness.csv')

df_2019 = df_2019.drop(columns=['Social_support'], axis = 1)

#print(df_2019)

# %%
df_2019.corr()
# Out:
#                 HappinessRank  HappinessScore   Economy    Health   Freedom  \
# HappinessRank        1.000000       -0.989096 -0.801947 -0.787411 -0.546606
# HappinessScore      -0.989096        1.000000  0.793883  0.779883  0.566742
# Economy             -0.801947        0.793883  1.000000  0.835462  0.379079
# Health              -0.787411        0.779883  0.835462  1.000000  0.390395
# Freedom             -0.546606        0.566742  0.379079  0.390395  1.000000
# Generosity          -0.047993        0.075824 -0.079662 -0.029511  0.269742
# Trust               -0.351959        0.385613  0.298920  0.295283  0.438843
#
#                 Generosity     Trust
# HappinessRank    -0.047993 -0.351959
# HappinessScore    0.075824  0.385613
# Economy          -0.079662  0.298920
# Health           -0.029511  0.295283
# Freedom           0.269742  0.438843
# Generosity        1.000000  0.326538
# Trust             0.326538  1.000000
